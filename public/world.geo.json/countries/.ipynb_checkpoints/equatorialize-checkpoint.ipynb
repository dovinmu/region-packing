# %%
import json
with open('../../centroids.json') as f:
    centroids = json.loads(f.read())
centroids['USA']
# Out:
# [-120.63441560508083, 45.11579279676678]

# %%
with open('RUS.geo.json') as f:
    rus = json.loads(f.read())
rus
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 'RUS',
#    'properties': {'name': 'Russia'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[143.648007, 50.7476],
#        [144.654148, 48.976391],
#        [143.173928, 49.306551],
#        [142.558668, 47.861575],
#        [143.533492, 46.836728],
#        [143.505277, 46.137908],
#        [142.747701, 46.740765],
#        [142.09203, 45.966755],
#        [141.906925, 46.805929],
#        [142.018443, 47.780133],
#        [141.904445, 48.859189],
#        [142.1358, 49.615163],
#        [142.179983, 50.952342],
#        [141.594076, 51.935435],
#        [141.682546, 53.301966],
#        [142.606934, 53.762145],
#        [142.209749, 54.225476],
#        [142.654786, 54.365881],
#        [142.914616, 53.704578],
#        [143.260848, 52.74076],
#        [143.235268, 51.75666],
#        [143.648007, 50.7476]]],
#      [[[22.731099, 54.327537],
#        [20.892245, 54.312525],
# ...

# %%
len(rus['features'])
# Out:
# 1

# %%
for i in range(len(rus['features'][0]['geometry']['coordinates'])):
    rus['features'][0]['geometry']['coordinates'][0] -= centroids['RUS'][0]
